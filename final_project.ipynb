# %%
from ultralytics import YOLO

# Aerial model
model_aerial = YOLO("models/aerial_model/best.pt")
model_aerial.predict(
    source="test_images/aerial",
    conf=0.4,
    save=True,
    project="results",
    name="aerial_results"
)

# Traffic model
model_traffic = YOLO("models/traffic_model/best.pt")
model_traffic.predict(
    source="test_images/traffic",
    conf=0.4,
    save=True,
    project="results",
    name="traffic_results"
)
# Out:
# image 1/11 c:\Users\TugceAyc\Desktop\GoruntuIsleme\Road_Object_Detection_Project\test_images\aerial\car&motor.png: 384x640 18 cars, 537.5ms
# image 2/11 c:\Users\TugceAyc\Desktop\GoruntuIsleme\Road_Object_Detection_Project\test_images\aerial\cars1.png: 384x640 3 cars, 297.5ms
# image 3/11 c:\Users\TugceAyc\Desktop\GoruntuIsleme\Road_Object_Detection_Project\test_images\aerial\cars11.jpg: 448x640 2 cars, 487.2ms
# image 4/11 c:\Users\TugceAyc\Desktop\GoruntuIsleme\Road_Object_Detection_Project\test_images\aerial\cars13.jpeg: 448x640 13 cars, 361.0ms
# image 5/11 c:\Users\TugceAyc\Desktop\GoruntuIsleme\Road_Object_Detection_Project\test_images\aerial\cars15.jpg: 384x640 15 cars, 311.0ms
# image 6/11 c:\Users\TugceAyc\Desktop\GoruntuIsleme\Road_Object_Detection_Project\test_images\aerial\cars3.jpg: 384x640 6 cars, 302.0ms
# image 7/11 c:\Users\TugceAyc\Desktop\GoruntuIsleme\Road_Object_Detection_Project\test_images\aerial\cars5.jpg: 416x640 14 cars, 427.2ms
# ...
